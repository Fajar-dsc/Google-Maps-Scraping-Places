# %%
import json
import csv
import requests
import time

url = 'https://maps.googleapis.com/maps/api/place/textsearch/json?query=Self Storage+in+Washington&key= #API Key'

headers={'content-type':'application/json',
         'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:63.0) Gecko/20100101 Firefox/63.0'}

def csv_write():
    csvfile =open('file name.csv','w') 
    writer = csv.writer(csvfile, delimiter=',')
    writer.writerow(["name","lat","long","vicinity"])

    response = requests.get(url=url, headers=headers).json()
    for obj in response['results']:
        writer.writerow ([obj['name'],obj['geometry']['location']['lat'],obj['geometry']['location']['lng'],obj['formatted_address']])
        
    
    else:
        print(response)
        
if __name__ == '__main__':
    csv_write()
# Out:
# {'html_attributions': [], 'next_page_token': 'ATtYBwJ24wIdYtyHiUpWHaXhQkTyX6my3VpK9KPxk66vHJVdgYyrggZEHwBzLTsnDg514Lmsrr_k29VACCR--Nh6NND-8viotO5J5nZE6tSWSC04-SARxdOvlhsZF2Npky3MDjVqCTIfVnZsQBW8glwcV7qnNDYk1TbEzddxNDbiduhVm2c6DSmUi9d_zfYoMjTO-Vm4lWMCKgzk-iV5DlwCAIKHofgw_YsYm_Gi2iX0zBIeOR1zGC1Ulip5pxAXor_3kszdNNkBfB6xl8rv4FNWEkAHl02rtv6lm8vZci6KpmlQooNTNQ-AidnSlXCTS1DMH2-xq-su-pf6PyJpw-3CjsGbck9yMyiv3lJisUdYkajJj8H72gHA9x7ktK5LRd-ThrUGfM77PY7gZ6KE7HgCbfG6agP4-FhFsHBOLx5A1RTY', 'results': [{'business_status': 'OPERATIONAL', 'formatted_address': 'Unnamed Road, Gambuhanblajo, Blajo, Kalitengah, Kabupaten Lamongan, Jawa Timur 62255, Indonesia', 'geometry': {'location': {'lat': -7.039034000000001, 'lng': 112.397037}, 'viewport': {'northeast': {'lat': -7.037683070107279, 'lng': 112.3983705798927}, 'southwest': {'lat': -7.040382729892722, 'lng': 112.3956709201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png', 'name': 'Warkop Rajhes', 'place_id': 'ChIJ-9FfsRrvdy4R-_laF-6wQro', 'plus_code': {'compound_code': 'X96W+9R Blajo, Lamongan Regency, East Java', 'global_code': '6P4JX96W+9R'}, 'rating': 0, 'reference': 'ChIJ-9FfsRrvdy4R-_laF-6wQro', 'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'], 'user_ratings_total': 0}, {'business_status': 'OPERATIONAL', 'formatted_address': 'Blajo, Kalitengah, Lamongan Regency, East Java 62255, Indonesia', 'geometry': {'location': {'lat': -7.0422201, 'lng': 112.3919113}, 'viewport': {'northeast': {'lat': -7.040842620107278, 'lng': 112.3932051798927}, 'southwest': {'lat': -7.043542279892722, 'lng': 112.3905055201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png', 'name': 'Warkop barokah jaya', 'place_id': 'ChIJm0GOuJDvdy4Rn1Nadezdv_Y', 'plus_code': {'compound_code': 'X95R+4Q Blajo, Lamongan Regency, East Java', 'global_code': '6P4JX95R+4Q'}, 'rating': 5, 'reference': 'ChIJm0GOuJDvdy4Rn1Nadezdv_Y', 'types': ['cafe', 'food', 'point_of_interest', 'establishment'], 'user_ratings_total': 1}, {'business_status': 'OPERATIONAL', 'formatted_address': 'Gambuhanblajo, Blajo, Kalitengah, Lamongan Regency, East Java 62255, Indonesia', 'geometry': {'location': {'lat': -7.039596899999999, 'lng': 112.3948737}, 'viewport': {'northeast': {'lat': -7.038195670107276, 'lng': 112.3960180798927}, 'southwest': {'lat': -7.04089532989272, 'lng': 112.3933184201073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png', 'name': 'Warkop Ashita', 'opening_hours': {'open_now': True}, 'place_id': 'ChIJq5rqlGTvdy4RZO7BOiru86g', 'plus_code': {'compound_code': 'X96V+5W Blajo, Lamongan Regency, East Java', 'global_code': '6P4JX96V+5W'}, 'rating': 0, 'reference': 'ChIJq5rqlGTvdy4RZO7BOiru86g', 'types': ['restaurant', 'food', 'point_of_interest', 'establishment'], 'user_ratings_total': 0}, {'business_status': 'OPERATIONAL', 'formatted_address': 'Berasan, Kemlagi Lor, Turi, Lamongan Regency, East Java 62252, Indonesia', 'geometry': {'location': {'lat': -7.0463495, 'lng': 112.3906869}, 'viewport': {'northeast': {'lat': -7.044991220107279, 'lng': 112.3919719298927}, 'southwest': {'lat': -7.047690879892722, 'lng': 112.3892722701073}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png', 'name': 'Warkop Aulya', 'opening_hours': {'open_now': False}, 'photos': [{'height': 768, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110110178745086638728">A Google User</a>'], 'photo_reference': 'ATtYBwKnbJiYtcWE9kY7CBNqDI_UtDbDsLvUs7tkvPDiLRgHeQt6MTln5SGUwCIY2Ow3y-f9W7ZTjpAkKQ8AZw5SfMQRmR1Ex8yvtWiF6ke7axFEghjwM9d9fZB69kpPvrCLoywAVREFq3a77gBmBQEAtZn95NBuM9uO_jU6I3rvWfJLK-Ei', 'width': 720}], 'place_id': 'ChIJeYXp_ijwdy4Rd6115bjQCjU', 'plus_code': {'compound_code': 'X93R+F7 Kemlagi Lor, Lamongan Regency, East Java', 'global_code': '6P4JX93R+F7'}, 'price_level': 1, 'rating': 4.3, 'reference': 'ChIJeYXp_ijwdy4Rd6115bjQCjU', 'types': ['cafe', 'food', 'point_of_interest', 'establ ...
